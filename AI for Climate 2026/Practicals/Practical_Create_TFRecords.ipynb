# %% [markdown]
# #Colab Setup (Required for Google Colab)
#
# **These cells are ONLY for running on Google Colab. Skip if running locally.**

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

# Create output directory in your Drive
OUTPUT_DIR = '/content/drive/MyDrive/my_tfrecords_2018'
os.makedirs(OUTPUT_DIR, exist_ok=True)

print(f"Output directory: {OUTPUT_DIR}")
# Out:
# Mounted at /content/drive
# Output directory: /content/drive/MyDrive/my_tfrecords_2018

# %%
# Clone the cGAN tutorial repository
# !git clone https://github.com/snath-xoc/cGAN_tutorial.git
# %cd cGAN_tutorial
# Out:
# Cloning into 'cGAN_tutorial'...
# remote: Enumerating objects: 260, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 260 (delta 12), reused 11 (delta 11), pack-reused 242 (from 1)
# Receiving objects: 100% (260/260), 7.54 MiB | 19.46 MiB/s, done.
# Resolving deltas: 100% (129/129), done.
# /content/cGAN_tutorial

# %%
# !pip install -q xarray netCDF4 gcsfs joblib pyyaml tensorflow cartopy

# Install proper crcmod for faster downloads
# !pip uninstall -y crcmod
# !pip install --no-cache-dir -U crcmod
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 76.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 101.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 45.4 MB/s eta 0:00:00
# WARNING: Skipping crcmod as it is not installed.
# Collecting crcmod
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 17.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: crcmod
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp312-cp312-linux_x86_64.whl size=31831 sha256=5c1bd00edd7e6fac611852a56a758f344224550806bec81a0471bdd05cb96e0b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-x5ooo6yc/wheels/76/08/0b/caa8b1380122cbfe6a03eaccbec0f63c67e619af4e30ca5e2a
# Successfully built crcmod
# Installing collected packages: crcmod
# Successfully installed crcmod-1.7

# %% [markdown]
# ### Download Raw Climate Data from GCS Buckets
#
# We'll download:
# - **IFS forecast data**
# - **IMERG satellite observations** (~25 GB)
# - **Normalization constants** and static fields

# %%
# choose which variables to download
# Option 1: All variables (
# FORECAST_VARIABLES = ['tp', 'cp', 't2m', 'tcwv', 'sp', 'v10', 'u10', 'cape', 'tclw', 'tciw', 'tcrw', 'tcw', 'ssr', 'mcc']

# Option 2: 4 variables only (
FORECAST_VARIABLES = ['tp', 't2m', 'tcwv', 'sp']

YEAR = 2018

print(f"Will download {len(FORECAST_VARIABLES)} variables: {FORECAST_VARIABLES}")
# Out:
# Will download 4 variables: ['tp', 't2m', 'tcwv', 'sp']

# %%
# directories for raw data (in colab)
RAW_IFS_DIR = f"/content/raw_ifs/{YEAR}/"
RAW_IMERG_DIR = "/content/raw_imerg/"
CONSTANTS_DIR = "/content/constants/"

os.makedirs(RAW_IFS_DIR, exist_ok=True)
os.makedirs(RAW_IMERG_DIR, exist_ok=True)
os.makedirs(CONSTANTS_DIR, exist_ok=True)

# %%
# Download IFS forecast data (7 minutes)
print(f" Downloading {len(FORECAST_VARIABLES)} variables")
print()

for var in FORECAST_VARIABLES:
    print(f"Downloading {var}.nc.")
    # !gsutil -m cp gs://sewaa-ifs-train/{YEAR}/{var}.nc {RAW_IFS_DIR}

print("\nIFS data downloaded")
# !ls -lh {RAW_IFS_DIR}
# Out:
#  Downloading 4 variables
#
# Downloading tp.nc.
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Copying gs://sewaa-ifs-train/2018/tp.nc...
# \ [1/1 files][  6.2 GiB/  6.2 GiB] 100% Done  67.0 MiB/s ETA 00:00:00
# Operation completed over 1 objects/6.2 GiB.
# Downloading t2m.nc.
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Copying gs://sewaa-ifs-train/2018/t2m.nc...
# | [1/1 files][  6.8 GiB/  6.8 GiB] 100% Done  56.9 MiB/s ETA 00:00:00
# Operation completed over 1 objects/6.8 GiB.
# Downloading tcwv.nc.
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Copying gs://sewaa-ifs-train/2018/tcwv.nc...
# \ [1/1 files][  7.3 GiB/  7.3 GiB] 100% Done  33.0 MiB/s ETA 00:00:00
# Operation completed over 1 objects/7.3 GiB.
# Downloading sp.nc.
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Copying gs://sewaa-ifs-train/2018/sp.nc...
# / [1/1 files][  6.5 GiB/  6.5 GiB] 100% Done  64.4 MiB/s ETA 00:00:00
# Operation completed over 1 objects/6.5 GiB.
#
# IFS data downloaded
# total 27G
# -rw-r--r-- 1 root root 6.6G Jun 10 11:05 sp.nc
# -rw-r--r-- 1 root root 6.8G Jun 10 11:01 t2m.nc
# -rw-r--r-- 1 root root 7.4G Jun 10 11:03 tcwv.nc
# -rw-r--r-- 1 root root 6.2G Jun 10 11:00 tp.nc

# %%
# Download IMERG observation data ( minutes)
print("Downloading IMERG observation data")
print()

# !gsutil -m cp -r gs://bucket_shruti_imerg/6h/{YEAR}/ {RAW_IMERG_DIR}

print("\n IMERG data downloaded")
# !ls {RAW_IMERG_DIR}{YEAR}/ | head -20
# Out:
# Downloading IMERG observation data
#
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Copying gs://bucket_shruti_imerg/6h/2018/20180101_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180101_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180101_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180101_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180102_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180102_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180102_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180103_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180103_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180102_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180103_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180104_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180103_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180104_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180104_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180104_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180105_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180105_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180105_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180105_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180106_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180106_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180106_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180106_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180107_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180107_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180107_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180107_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180108_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180108_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180108_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180108_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180109_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180109_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180109_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180109_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180110_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180110_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180110_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180110_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180111_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180111_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180111_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180111_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180112_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180112_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180112_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180112_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180113_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180113_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180113_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180113_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180114_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180114_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180114_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180114_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180115_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180115_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180115_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180115_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180116_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180116_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180116_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180116_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180117_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180117_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180117_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180117_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180118_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180118_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180118_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180118_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180119_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180119_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180119_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180119_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180120_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180120_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180120_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180120_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180121_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180121_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180121_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180121_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180122_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180122_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180122_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180122_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180123_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180123_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180123_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180123_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180124_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180124_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180124_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180124_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180125_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180125_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180125_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180125_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180126_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180126_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180126_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180126_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180127_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180127_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180127_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180127_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180128_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180128_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180128_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180128_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180129_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180129_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180129_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180129_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180130_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180130_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180130_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180130_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180131_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180131_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180131_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180131_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180201_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180201_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180201_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180201_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180202_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180202_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180202_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180202_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180203_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180203_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180203_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180203_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180204_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180204_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180204_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180204_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180205_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180205_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180205_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180205_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180206_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180206_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180206_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180206_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180207_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180207_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180207_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180207_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180208_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180208_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180208_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180208_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180209_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180209_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180209_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180209_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180210_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180210_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180210_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180210_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180211_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180211_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180211_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180211_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180212_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180212_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180212_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180212_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180213_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180213_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180213_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180213_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180214_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180214_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180214_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180214_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180215_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180215_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180215_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180215_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180216_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180216_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180216_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180216_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180217_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180217_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180217_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180217_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180218_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180218_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180218_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180218_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180219_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180219_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180219_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180219_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180220_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180220_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180220_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180220_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180221_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180221_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180221_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180221_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180222_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180222_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180222_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180222_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180223_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180223_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180223_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180223_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180224_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180224_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180224_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180224_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180225_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180225_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180225_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180225_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180226_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180226_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180226_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180226_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180227_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180227_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180227_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180227_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180228_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180228_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180228_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180228_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180301_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180301_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180301_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180301_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180302_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180302_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180302_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180302_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180303_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180303_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180303_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180303_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180304_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180304_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180304_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180304_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180305_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180305_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180305_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180305_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180306_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180306_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180306_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180306_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180307_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180307_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180307_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180307_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180308_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180308_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180308_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180309_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180308_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180309_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180309_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180309_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180310_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180310_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180310_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180310_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180311_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180311_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180311_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180311_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180312_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180312_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180312_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180312_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180313_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180313_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180313_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180313_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180314_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180314_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180314_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180314_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180315_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180315_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180315_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180315_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180316_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180316_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180316_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180316_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180317_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180317_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180317_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180317_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180318_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180318_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180318_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180318_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180319_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180319_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180319_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180319_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180320_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180320_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180320_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180320_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180321_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180321_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180321_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180321_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180322_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180322_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180322_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180322_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180323_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180323_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180323_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180323_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180324_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180324_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180324_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180324_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180325_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180325_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180325_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180325_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180326_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180326_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180326_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180326_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180327_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180327_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180327_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180327_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180328_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180328_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180328_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180328_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180329_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180329_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180329_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180329_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180330_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180330_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180330_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180330_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180331_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180331_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180331_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180331_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180401_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180401_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180401_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180401_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180402_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180402_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180402_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180402_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180403_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180403_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180403_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180403_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180404_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180404_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180404_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180404_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180405_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180405_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180405_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180405_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180406_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180406_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180406_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180406_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180407_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180407_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180407_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180407_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180408_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180408_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180408_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180408_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180409_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180409_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180409_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180409_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180410_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180410_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180410_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180410_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180411_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180411_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180411_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180411_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180412_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180412_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180412_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180412_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180413_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180413_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180413_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180413_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180414_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180414_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180414_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180414_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180415_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180415_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180415_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180415_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180416_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180416_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180416_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180416_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180417_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180417_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180417_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180417_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180418_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180418_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180418_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180419_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180418_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180419_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180419_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180419_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180420_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180420_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180420_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180420_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180421_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180421_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180421_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180421_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180422_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180422_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180422_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180422_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180423_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180423_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180423_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180423_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180424_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180424_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180424_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180424_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180425_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180425_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180425_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180425_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180426_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180426_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180426_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180426_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180427_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180427_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180427_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180427_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180428_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180428_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180428_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180428_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180429_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180429_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180429_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180429_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180430_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180430_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180430_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180430_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180501_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180501_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180501_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180501_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180502_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180502_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180502_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180502_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180503_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180503_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180503_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180503_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180504_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180504_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180504_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180504_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180505_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180505_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180505_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180505_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180506_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180506_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180506_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180506_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180507_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180507_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180507_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180507_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180508_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180508_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180508_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180508_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180509_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180509_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180509_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180509_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180510_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180510_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180510_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180510_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180511_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180511_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180511_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180511_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180512_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180512_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180512_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180512_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180513_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180513_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180513_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180513_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180514_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180514_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180514_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180514_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180515_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180515_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180515_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180515_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180516_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180516_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180516_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180516_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180517_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180517_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180517_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180517_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180518_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180518_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180518_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180518_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180519_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180519_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180519_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180519_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180520_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180520_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180520_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180520_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180521_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180521_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180521_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180521_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180522_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180522_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180522_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180522_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180523_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180523_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180523_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180523_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180524_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180524_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180524_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180524_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180525_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180525_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180525_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180525_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180526_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180526_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180526_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180526_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180527_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180527_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180527_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180527_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180528_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180528_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180528_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180528_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180529_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180529_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180529_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180529_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180530_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180530_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180530_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180530_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180531_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180531_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180531_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180531_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180601_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180601_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180601_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180601_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180602_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180602_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180602_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180602_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180603_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180603_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180603_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180603_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180604_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180604_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180604_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180604_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180605_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180605_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180605_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180605_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180606_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180606_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180606_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180606_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180607_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180607_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180607_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180607_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180608_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180608_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180608_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180608_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180609_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180609_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180609_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180609_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180610_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180610_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180610_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180610_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180611_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180611_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180611_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180611_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180612_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180612_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180612_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180612_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180613_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180613_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180613_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180614_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180613_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180614_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180614_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180614_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180615_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180615_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180615_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180615_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180616_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180616_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180616_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180616_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180617_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180617_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180617_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180617_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180618_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180618_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180618_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180618_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180619_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180619_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180619_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180619_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180620_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180620_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180620_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180620_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180621_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180621_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180621_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180621_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180622_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180622_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180622_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180622_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180623_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180623_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180623_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180623_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180624_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180624_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180624_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180624_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180625_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180625_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180625_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180625_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180626_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180626_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180626_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180626_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180627_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180627_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180627_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180627_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180628_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180628_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180628_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180628_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180629_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180629_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180629_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180629_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180630_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180630_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180630_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180630_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180701_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180701_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180701_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180701_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180702_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180702_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180702_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180702_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180703_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180703_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180703_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180703_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180704_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180704_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180704_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180704_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180705_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180705_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180705_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180705_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180706_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180706_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180706_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180706_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180707_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180707_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180707_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180707_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180708_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180708_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180708_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180708_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180709_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180709_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180709_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180709_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180710_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180710_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180710_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180710_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180711_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180711_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180711_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180711_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180712_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180712_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180712_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180712_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180713_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180713_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180713_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180713_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180714_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180714_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180714_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180714_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180715_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180715_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180715_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180715_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180716_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180716_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180716_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180716_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180717_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180717_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180717_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180717_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180718_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180718_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180718_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180718_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180719_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180719_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180719_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180719_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180720_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180720_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180720_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180720_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180721_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180721_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180721_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20180721_18.nc...
# ...
# Copying gs://bucket_shruti_imerg/6h/2018/20181027_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181028_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181027_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181028_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181028_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181028_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181029_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181029_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181029_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181029_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181030_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181030_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181030_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181030_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181031_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181031_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181031_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181031_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181101_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181101_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181101_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181101_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181102_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181102_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181102_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181102_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181103_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181103_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181103_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181103_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181104_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181104_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181104_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181104_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181105_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181105_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181105_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181105_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181106_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181106_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181106_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181106_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181107_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181107_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181107_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181107_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181108_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181108_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181108_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181108_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181109_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181109_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181109_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181109_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181110_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181110_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181110_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181110_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181111_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181111_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181111_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181111_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181112_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181112_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181112_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181112_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181113_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181113_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181113_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181113_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181114_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181114_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181114_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181114_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181115_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181115_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181115_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181115_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181116_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181116_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181116_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181116_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181117_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181117_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181117_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181117_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181118_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181118_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181118_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181118_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181119_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181119_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181119_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181119_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181120_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181120_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181120_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181120_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181121_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181121_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181121_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181121_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181122_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181122_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181122_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181122_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181123_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181123_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181123_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181123_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181124_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181124_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181124_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181124_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181125_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181125_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181125_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181125_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181126_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181126_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181126_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181126_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181127_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181127_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181127_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181128_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181127_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181128_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181128_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181128_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181129_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181129_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181129_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181129_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181130_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181130_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181130_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181130_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181201_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181201_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181201_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181201_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181202_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181202_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181202_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181202_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181203_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181203_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181203_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181203_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181204_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181204_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181204_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181204_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181205_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181205_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181205_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181205_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181206_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181206_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181206_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181206_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181207_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181207_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181207_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181207_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181208_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181208_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181208_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181208_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181209_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181209_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181209_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181209_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181210_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181210_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181210_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181210_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181211_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181211_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181211_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181211_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181212_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181212_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181212_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181212_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181213_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181213_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181213_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181214_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181213_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181214_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181214_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181214_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181215_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181215_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181215_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181215_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181216_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181216_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181216_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181216_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181217_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181217_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181217_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181217_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181218_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181218_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181218_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181219_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181218_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181219_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181219_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181219_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181220_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181220_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181220_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181220_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181221_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181221_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181221_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181221_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181222_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181222_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181222_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181222_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181223_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181223_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181223_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181223_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181224_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181224_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181224_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181224_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181225_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181225_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181225_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181225_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181226_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181226_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181226_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181226_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181227_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181227_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181227_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181227_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181228_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181228_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181228_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181228_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181229_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181229_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181229_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181229_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181230_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181230_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181230_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181230_18.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181231_00.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181231_06.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181231_12.nc...
# Copying gs://bucket_shruti_imerg/6h/2018/20181231_18.nc...
# - [1.5k/1.5k files][161.2 MiB/161.2 MiB] 100% Done   1.3 MiB/s ETA 00:00:00
# Operation completed over 1.5k objects/161.2 MiB.
#
#  IMERG data downloaded
# 20180101_00.nc
# 20180101_06.nc
# 20180101_12.nc
# 20180101_18.nc
# 20180102_00.nc
# 20180102_06.nc
# 20180102_12.nc
# 20180102_18.nc
# 20180103_00.nc
# 20180103_06.nc
# 20180103_12.nc
# 20180103_18.nc
# 20180104_00.nc
# 20180104_06.nc
# 20180104_12.nc
# 20180104_18.nc
# 20180105_00.nc
# 20180105_06.nc
# 20180105_12.nc
# 20180105_18.nc

# %%
# Download normalization constants and static fields
print("Downloading constants (normalization, elev, lsm)")

# !gsutil cp gs://sewaa-ifs-train/constants/FCSTNorm_IFS/FCSTNorm{YEAR}.pkl {CONSTANTS_DIR}
# !gsutil cp gs://sewaa-ifs-train/constants/elev.nc {CONSTANTS_DIR}
# !gsutil cp gs://sewaa-ifs-train/constants/lsm.nc {CONSTANTS_DIR}


# !ls -lh {CONSTANTS_DIR}
# Out:
# Downloading constants (normalization, elev, lsm)
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Copying gs://sewaa-ifs-train/constants/FCSTNorm_IFS/FCSTNorm2018.pkl...
# / [1 files][  1.3 KiB/  1.3 KiB]
# Operation completed over 1 objects/1.3 KiB.
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Copying gs://sewaa-ifs-train/constants/elev.nc...
# - [1 files][541.8 KiB/541.8 KiB]
# Operation completed over 1 objects/541.8 KiB.
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Copying gs://sewaa-ifs-train/constants/lsm.nc...
# - [1 files][540.9 KiB/540.9 KiB]
# Operation completed over 1 objects/540.9 KiB.
# total 1.1M
# -rw-r--r-- 1 root root 542K Jun 10 11:11 elev.nc
# -rw-r--r-- 1 root root 1.4K Jun 10 11:11 FCSTNorm2018.pkl
# -rw-r--r-- 1 root root 541K Jun 10 11:11 lsm.nc

# %% [markdown]
# ### Create Configuration Files
#
# Set up paths to point to our downloaded data.

# %%
# Create data_paths.yaml configuration
data_paths_content = f"""ICPAC_CLOUD:
  GENERAL:
    FORECAST_PATH: "/content/raw_ifs/"
    TRUTH_PATH: "/content/raw_imerg/"
    CONSTANTS_PATH: "{CONSTANTS_DIR}"

  TFRecords:
    tfrecords_path: "{OUTPUT_DIR}/"
"""

local_config_content = """data_paths: 'ICPAC_CLOUD'
"""

with open('config/data_paths.yaml', 'w') as f:
    f.write(data_paths_content)

with open('config/local_config.yaml', 'w') as f:
    f.write(local_config_content)

# %% [markdown]
# # Import functions and set TF_USE_LEGACY_KERAS = 1 (necessary only for tensorflow version >= 2.16.0)

# %%
import os

# Only needed for tensorflow versions greater than 2.16.0
# os.environ["TF_USE_LEGACY_KERAS"] = "1"

import sys
import joblib
sys.path.insert(1,"../")
from data import write_data, gen_fcst_norm
import numpy as np
from config import get_data_paths

# %% [markdown]
# ### Override all_fcst_fields

# %%
# Patch the data module to use only the downloaded variables
import data
from datetime import datetime, timedelta

data.all_fcst_fields = FORECAST_VARIABLES

# (original version checks if files exist)
def get_dates_all(year, start_hour, end_hour):
    """Generate all dates for the year"""
    start_date = datetime(year, 1, 1)
    end_date = datetime(year, 12, 31)
    dates = []
    current = start_date
    while current <= end_date:
        dates.append(current.strftime('%Y%m%d'))
        current += timedelta(days=1)
    return dates

data.get_dates = get_dates_all


print(f"   Variables: {data.all_fcst_fields}")
# Out:
#    Variables: ['tp', 't2m', 'tcwv', 'sp']

# %% [markdown]
# ## We retrieve the data paths set in [**config/data_paths.yaml**](https://github.com/snath-xoc/cGAN_tutorial/blob/main/config/data_paths.yaml) and check that they are correctly set. We also set the year that is used to generate normalisation constants

# %%
data_paths = get_data_paths()
CONSTANTS_PATH = data_paths["GENERAL"]["CONSTANTS_PATH"]
FCSTNorm_year = "2018"

print("Sanity check that these data paths are correctly set:\n")
print("FORECAST_PATH:",data_paths["GENERAL"]["FORECAST_PATH"])
print("CONSTANTS_PATH:",data_paths["GENERAL"]["CONSTANTS_PATH"])
print("TRUTH_PATH:",data_paths["GENERAL"]["TRUTH_PATH"])
print("TFRecords path:",data_paths["TFRecords"]["tfrecords_path"])
# Out:
# Sanity check that these data paths are correctly set:
#
# FORECAST_PATH: /content/raw_ifs/
# CONSTANTS_PATH: /content/constants/
# TRUTH_PATH: /content/raw_imerg/
# TFRecords path: /content/drive/MyDrive/my_tfrecords_2018/

# %% [markdown]
# # Forecast normalisation constants
# ### Typically for AI approaches, training and optimisation as well as inference works best when the values are normalised in a manner that retains the original distirbution. We therefore calculate a set of forecast normalisation constants for the region with which to normalise the variables with. These normalisation constants include the mean, std, min and max.
#
# ### We normalise accordingly:
# #### a) Precipitation variables of total precipitation (tp) and convective precipitation (cp) follow a log normalisation (i.e. log10(1+x) ).
# #### b) 2m temperature (t2m) and surface pressure (sp) are reasonable normally distributed so we use a simple standard normalisation of (x-mean)/std.
# #### c) Other variables are bounded to be non-negative (e.g., cape, tclw, tciw, tcrw, tcwv,tcw) and divided through by their maximum: x/max.
# #### d) Wind (both u and v components) can be negative and are therefore divided by their absolute maximum: x/maxima(abs(min),abs(max)).
# #### e) It is worth noting that Shortwave Solar Radiation (ssr) is an accumulated variables and needs to be converted from per second to per hour (i.e. x/3600).
# #### f) Medium Cloud Cover (mcc) does not require any normalisation (as it is a fractional value bounded at 0-1).

# %% [markdown]
# ##Mean, STD, min, max

# %%
if not os.path.exists(CONSTANTS_PATH+f"FCSTNorm{FCSTNorm_year}.pkl"):
    gen_fcst_norm(year=FCSTNorm_year)
    fcstNorm = joblib.load(CONSTANTS_PATH+f"FCSTNorm{FCSTNorm_year}.pkl")
else:
    fcstNorm = joblib.load(CONSTANTS_PATH+f"FCSTNorm{FCSTNorm_year}.pkl")

print(fcstNorm)
# Out:
# {'cape': {'min': np.float32(0.0), 'max': np.float32(12028.97), 'mean': np.float64(372.25190070517834), 'std': np.float64(634.6625669909214)}, 'cp': {'min': np.float32(0.0), 'max': np.float32(11.575001), 'mean': np.float64(0.07430827387592304), 'std': np.float64(0.15727741289177508)}, 'mcc': {'min': np.float32(0.0), 'max': np.float32(1.0), 'mean': np.float64(0.1449043023444736), 'std': np.float64(0.15871610393337535)}, 'sp': {'min': np.float32(65720.24), 'max': np.float32(103549.266), 'mean': np.float64(94920.06952099419), 'std': np.float64(5503.212221379535)}, 'ssr': {'min': np.float32(-0.0431156), 'max': np.float32(924.5827), 'mean': np.float64(196.8274811061243), 'std': np.float64(235.30287313931277)}, 't2m': {'min': np.float32(270.85034), 'max': np.float32(321.96042), 'mean': np.float64(298.3595823336004), 'std': np.float64(5.641285692771801)}, 'tciw': {'min': np.float32(0.0), 'max': np.float32(2.5885322), 'mean': np.float64(0.014063224684635873), 'std': np.float64(0.028363458486443126)}, 'tclw': {'min': np.float32(0.0), 'max': np.float32(3.4733133), 'mean': np.float64(0.03823531449178857), 'std': np.float64(0.04313131040707701)}, 'tcrw': {'min': np.float32(0.0), 'max': np.float32(14.966368), 'mean': np.float64(0.009420234312671727), 'std': np.float64(0.022581907459965727)}, 'tcw': {'min': np.float32(0.47369844), 'max': np.float32(123.179535), 'mean': np.float64(30.90023667667402), 'std': np.float64(13.09838759314808)}, 'tcwv': {'min': np.float32(0.4736635), 'max': np.float32(76.853516), 'mean': np.float64(30.808693147700946), 'std': np.float64(13.027879880832117)}, 'tp': {'min': np.float32(0.0), 'max': np.float32(23.430689), 'mean': np.float64(0.09576654853046822), 'std': np.float64(0.19855568598172443)}, 'u700': {'min': np.float32(-34.587498), 'max': np.float32(32.612293), 'mean': np.float64(-1.306787209497039), 'std': np.float64(4.9323835011998876)}, 'v700': {'min': np.float32(-36.457127), 'max': np.float32(32.55248), 'mean': np.float64(-0.5620318767078737), 'std': np.float64(3.580560675508342)}}

# %% [markdown]
# # Data Generator
# ### As mentioned in the data module directory, a key part to the data load-in is the ```DataGenerator``` class from the [**data/data_generator.py**](https://github.com/snath-xoc/cGAN_tutorial/blob/main/data/data_generator.py) file.
#
# ### The ```DataGenerator``` calls the ```load_fcst_truth_batch``` function from [**data/data.py**](https://github.com/snath-xoc/cGAN_tutorial/blob/main/data/data.py#L157) that for a given date will:<br>1) Load in all desired forecast variables (i.e., using ```load_fcst_stack```)<br>2) Load in the truth variables (i.e., ```load_truth_and_mask```)<br>
#
# ### Once all file paths specified in [**config/data_paths.yaml**](https://github.com/snath-xoc/cGAN_tutorial/blob/main/config/data_paths.yaml) and [**config/local_config.yaml**](https://github.com/snath-xoc/cGAN_tutorial/blob/main/config/local_config.yaml) are set properly in the config directory we can initialise the data generator and visualise that everything looks alright

# %% [markdown]
# ### Initialisation of the data generator:
#
# #### First import the DataGenerator alongside the forecast fields (```all_fcst_fields```) from the data module. We also check which dates are available for the example year 2018 and fcst time horizon of 30 hour to 54 hour ahead using the ```get_dates``` function

# %%
##Example load-in
from data import DataGenerator, all_fcst_fields, get_dates

print("Looking into getting dates for the forecast fields:\n", all_fcst_fields,"\n")

year = 2018
start_hour = 30
end_hour = 54
dates = get_dates(year, start_hour, end_hour)

print(f"Available dates for the year {year} and forecast lead times of {start_hour} to {end_hour} are:", dates)
# Out:
# Looking into getting dates for the forecast fields:
#  ['tp', 't2m', 'tcwv', 'sp']
#
# Available dates for the year 2018 and forecast lead times of 30 to 54 are: ['20180101', '20180102', '20180103', '20180104', '20180105', '20180106', '20180107', '20180108', '20180109', '20180110', '20180111', '20180112', '20180113', '20180114', '20180115', '20180116', '20180117', '20180118', '20180119', '20180120', '20180121', '20180122', '20180123', '20180124', '20180125', '20180126', '20180127', '20180128', '20180129', '20180130', '20180131', '20180201', '20180202', '20180203', '20180204', '20180205', '20180206', '20180207', '20180208', '20180209', '20180210', '20180211', '20180212', '20180213', '20180214', '20180215', '20180216', '20180217', '20180218', '20180219', '20180220', '20180221', '20180222', '20180223', '20180224', '20180225', '20180226', '20180227', '20180228', '20180301', '20180302', '20180303', '20180304', '20180305', '20180306', '20180307', '20180308', '20180309', '20180310', '20180311', '20180312', '20180313', '20180314', '20180315', '20180316', '20180317', '20180318', '20180319', '20180320', '20180321', '20180322', '20180323', '20180324', '20180325', '20180326', '20180327', '20180328', '20180329', '20180330', '20180331', '20180401', '20180402', '20180403', '20180404', '20180405', '20180406', '20180407', '20180408', '20180409', '20180410', '20180411', '20180412', '20180413', '20180414', '20180415', '20180416', '20180417', '20180418', '20180419', '20180420', '20180421', '20180422', '20180423', '20180424', '20180425', '20180426', '20180427', '20180428', '20180429', '20180430', '20180501', '20180502', '20180503', '20180504', '20180505', '20180506', '20180507', '20180508', '20180509', '20180510', '20180511', '20180512', '20180513', '20180514', '20180515', '20180516', '20180517', '20180518', '20180519', '20180520', '20180521', '20180522', '20180523', '20180524', '20180525', '20180526', '20180527', '20180528', '20180529', '20180530', '20180531', '20180601', '20180602', '20180603', '20180604', '20180605', '20180606', '20180607', '20180608', '20180609', '20180610', '20180611', '20180612', '20180613', '20180614', '20180615', '20180616', '20180617', '20180618', '20180619', '20180620', '20180621', '20180622', '20180623', '20180624', '20180625', '20180626', '20180627', '20180628', '20180629', '20180630', '20180701', '20180702', '20180703', '20180704', '20180705', '20180706', '20180707', '20180708', '20180709', '20180710', '20180711', '20180712', '20180713', '20180714', '20180715', '20180716', '20180717', '20180718', '20180719', '20180720', '20180721', '20180722', '20180723', '20180724', '20180725', '20180726', '20180727', '20180728', '20180729', '20180730', '20180731', '20180801', '20180802', '20180803', '20180804', '20180805', '20180806', '20180807', '20180808', '20180809', '20180810', '20180811', '20180812', '20180813', '20180814', '20180815', '20180816', '20180817', '20180818', '20180819', '20180820', '20180821', '20180822', '20180823', '20180824', '20180825', '20180826', '20180827', '20180828', '20180829', '20180830', '20180831', '20180901', '20180902', '20180903', '20180904', '20180905', '20180906', '20180907', '20180908', '20180909', '20180910', '20180911', '20180912', '20180913', '20180914', '20180915', '20180916', '20180917', '20180918', '20180919', '20180920', '20180921', '20180922', '20180923', '20180924', '20180925', '20180926', '20180927', '20180928', '20180929', '20180930', '20181001', '20181002', '20181003', '20181004', '20181005', '20181006', '20181007', '20181008', '20181009', '20181010', '20181011', '20181012', '20181013', '20181014', '20181015', '20181016', '20181017', '20181018', '20181019', '20181020', '20181021', '20181022', '20181023', '20181024', '20181025', '20181026', '20181027', '20181028', '20181029', '20181030', '20181031', '20181101', '20181102', '20181103', '20181104', '20181105', '20181106', '20181107', '20181108', '20181109', '20181110', '20181111', '20181112', '20181113', '20181114', '20181115', '20181116', '20181117', '20181118', '20181119', '20181120', '20181121', '20181122', '20181123',  ...

# %% [markdown]
# ### Now we instantiate the DataGenerator, the main arguments are:
#
# #### dates: list, positional argument that is a list of dates to load in<br> fcst_fields: list, which forecast variables to load in (we use all the forecast fields as printed above)<br> start_hour: int, the first lead time to load in (we usually use 30 hours)<br> end_hour: int, the last lead time up to which to load in (usually 54 hours)<br> batch_size: int<br> shuffle: Boolean<br> constants: Boolean, whether to use land-sea mask and elevation constants<br> fcst_norm: Boolean, whether to normalise forecast variables

# %%
test_idx_till = 20

dgc = DataGenerator(dates[:test_idx_till],
                       fcst_fields=all_fcst_fields,
                                start_hour=start_hour,
                                end_hour=end_hour,
                                batch_size=1,
                                log_precip=True,
                                shuffle=False,
                                constants=True,
                                fcst_norm=True)

# %% [markdown]
# ### Next we draw a sample by calling the ```__getitem__``` function of the ```DataGenerator```. The sample itself should be a tuple with:
# #### 1) A dictionary of:<br>&nbsp;&nbsp; a) lo_res_inputs: the forecast inputs going into the GAN, this is an array of size (```batch_size, lat, lon, n_variables```). For our domain ```lat=384``` and ```lon=352```. Our forecast list printed above has 14 variables, for each variable we take the ensemble mean and standard deviation at the lead time of interest, and the lead time of interest + 6. This means that we have ```n_variables=14*2*2=56```.<br>&nbsp;&nbsp; b) hi_res_inputs: constant inputs of elevation and land-sea mask, this is an array of size (```batch_size, lat, lon, 2```)
# #### 2)  A dictionary of:<br>&nbsp;&nbsp; a) output: truth data, an array of (```batch_size, lat, lon```).<br>&nbsp;&nbsp; b) mask: mask containing invalid points in the truth data, an array of (```batch_size, lat, lon```)

# %%
sample = dgc.__getitem__(0)

keys = [k for k in sample[0].keys()]
shapes = [sample[0][k].shape for k in sample[0].keys()]
print("Sample consisting of a tuple has been retrieved. Keys for the first component are:", keys)
print("The corresponding shapes are:")
for key, shape in zip(keys,shapes):
    print(key,":",shape)
keys = [k for k in sample[1].keys()]
shapes = [sample[1][k].shape for k in sample[1].keys()]

print("\n")
print("Keys for the second component are:", keys)
print("The corresponding shapes are:")
for key, shape in zip(keys,shapes):
    print(key,":",shape)
# Out:
# Sample consisting of a tuple has been retrieved. Keys for the first component are: ['lo_res_inputs', 'hi_res_inputs']
# The corresponding shapes are:
# lo_res_inputs : (1, 384, 352, 16)
# hi_res_inputs : (1, 384, 352, 2)
#
#
# Keys for the second component are: ['output', 'mask']
# The corresponding shapes are:
# output : (1, 384, 352)
# mask : (1, 384, 352)

# %% [markdown]
# ### Next we visualise the loaded in values, an easy first one to check are the constant fields of elevation and land-sea mask

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np

ax = plt.axes(projection = ccrs.PlateCarree())

lats = np.arange(-13.65,24.65+0.1,0.1)
lons = np.arange(19.15,54.25+0.1,0.1)

mesh = ax.pcolormesh(lons, lats, sample[0]['hi_res_inputs'][0,:,:,0], cmap='terrain_r')
plt.colorbar(mesh)
plt.title('elevation')
plt.show()
plt.close()

ax = plt.axes(projection = ccrs.PlateCarree())

mesh = ax.pcolormesh(lons, lats, sample[0]['hi_res_inputs'][0,:,:,1], cmap='Blues')
plt.colorbar(mesh)
plt.title('land-sea mask')
# Out:
# Text(0.5, 1.0, 'land-sea mask')

# %% [markdown]
# ### Now we can try a variable such as surface pressure

# %%
# plot the variable mean for the first time step
# feel free to change the variables
var = "sp"
idx = all_fcst_fields.index(var)*4

ax = plt.axes(projection = ccrs.PlateCarree())

lats = np.arange(-13.65,24.65+0.1,0.1)
lons = np.arange(19.15,54.25+0.1,0.1)

mesh = ax.pcolormesh(lons, lats, sample[0]['lo_res_inputs'][0,:,:,idx], cmap='Reds')
plt.colorbar(mesh)
plt.title(f"{var} mean")
# Out:
# Text(0.5, 1.0, 'sp mean')

# %% [markdown]
# ### Now we can start writing the tfrecord files by calling the ```write_data``` function. Good to know beforehand:
# #### The ```write_data``` function is loaded from [**data/tfrecords_generator.py**](https://github.com/snath-xoc/cGAN_tutorial/blob/main/data/tfrecords_generator.py#L208). We write tfrecords into a file using the naming convention:
#
# #### {year}_{leadtime}.{class}.tfrecords
#
# #### Where the class represents a certain range of rainfall. The number of classes is specified under ```CLASSES``` in ```L23``` of the [**data/tfrecords_generator.py**](https://github.com/snath-xoc/cGAN_tutorial/blob/main/data/tfrecords_generator.py#L23), with the respective class bins specified under ```bins``` in [**data/tfrecords_generator.py**](https://github.com/snath-xoc/cGAN_tutorial/blob/main/data/tfrecords_generator.py#L226).
#
# #### Typically we patch up the domain into **128x128 pixel** blocks during training, you can see this specified under ```DEFAULT_FCST_SHAPE```,  ```DEFAULT_CON_SHAPE``` and ```DEFAULT_OUT_SHAPE``` in [**data/tfrecords_generator.py**](https://github.com/snath-xoc/cGAN_tutorial/blob/main/data/tfrecords_generator.py#L24).

# %% [markdown]
# ---
#
# ## NOTE:
#
# The original write_data() function only processes 8 dates instead of all 365 dates for the year.
#
# **Two options below:**
# - **Option A:** Run original code
# - **Option B:** Run over all 365 dates
#
#
#
# ---

# %% [markdown]
# ### Option A: Original Code

# %% [markdown]
# from data import write_data
#
# years = [2018]
#
# for year in years:
#     # write_data(year)
#     write_data(year, fcst_fields=FORECAST_VARIABLES)

# %% [markdown]
# ### Option B: (Processes ALL 365 dates) (10 mins)

# %%
# Option B:(processes ALL 365 dates)
from data.tfrecords_generator import DataGeneratorFull, _float_feature, denormalise
from data import get_dates
import tensorflow as tf
import numpy as np
import random
from tqdm import tqdm
from datetime import datetime as dt

# Which lead times to process:
# Options: [30], [30, 36], [30, 36, 42, 48]
LEAD_TIMES = [30]

print(f"Year: {year}")
print(f"Lead times: {LEAD_TIMES}")
print(f"Output: {data_paths['TFRecords']['tfrecords_path']}")


import time
total_start = time.time()

# Settings
img_size_h, img_size_w = 384, 352
img_chunk_width = 128
num_class = 4
bins = [0.2, 0.3, 0.45]

for time_idx in LEAD_TIMES:
    print(f"\n{'='*70}")
    print(f"Processing time index {time_idx}h")
    print(f"{'='*70}")

    # Get dates for this lead time
    dates = get_dates(year, start_hour=time_idx, end_hour=time_idx+6)
    print(f"Dates to process: {len(dates)}")

    # Create data generator
    dgc = DataGeneratorFull(
        dates,
        fcst_fields=all_fcst_fields,
        start_hour=time_idx,
        end_hour=time_idx+6,
        batch_size=1,
        log_precip=True,
        shuffle=False,
        constants=True,
        fcst_norm=True,
    )

    # Open TFRecord writers (one per precipitation class)
    fle_hdles = []
    tfrecords_path = data_paths['TFRecords']['tfrecords_path']
    for fh in range(num_class):
        flename = os.path.join(tfrecords_path, f"{year}_{time_idx}.{fh}.tfrecords")
        options = tf.io.TFRecordOptions(compression_type="GZIP")
        fle_hdles.append(tf.io.TFRecordWriter(flename, options=options))

    samples_written = 0

    # Process ALL dates (fixed from original which only did 8)
    for batch_idx in tqdm(range(len(dates)), desc=f"{time_idx}h"):
        try:
            sample = dgc.__getitem__(batch_idx)

            # Create 8 random patches from each date
            for _ in range(8):
                idh = random.randint(0, img_size_h - img_chunk_width)
                idw = random.randint(0, img_size_w - img_chunk_width)

                mask = sample[1]["mask"][0, idh:idh+img_chunk_width, idw:idw+img_chunk_width].flatten()
                if np.any(mask):
                    continue  # Skip invalid patches

                truth = sample[1]["output"][0, idh:idh+img_chunk_width, idw:idw+img_chunk_width].flatten()
                const = sample[0]["hi_res_inputs"][0, idh:idh+img_chunk_width, idw:idw+img_chunk_width, :].flatten()
                forecast = sample[0]["lo_res_inputs"][0, idh:idh+img_chunk_width, idw:idw+img_chunk_width, :].flatten()

                # Create TFRecord example
                feature = {
                    "generator_input": _float_feature(forecast),
                    "constants": _float_feature(const),
                    "generator_output": _float_feature(truth),
                }
                example = tf.train.Example(features=tf.train.Features(feature=feature))

                # Classify by rainfall amount
                truth_raw = denormalise(truth)
                if len(truth_raw) == 0:
                    continue
                truth_mean = truth_raw.mean()

                if truth_mean < bins[0]:
                    clss = 0
                elif truth_mean < bins[1]:
                    clss = 1
                elif truth_mean < bins[2]:
                    clss = 2
                else:
                    clss = 3

                fle_hdles[clss].write(example.SerializeToString())
                samples_written += 1

        except FileNotFoundError as e:
            # Skip dates that need next year's data
            continue

    # Close files
    for fh in fle_hdles:
        fh.close()

    print(f"Completed {time_idx}h - {samples_written} samples written")
# Out:
# Year: 2018
# Lead times: [30]
# Output: /content/drive/MyDrive/my_tfrecords_2018/
#
# ======================================================================
# Processing time index 30h
# ======================================================================
# Dates to process: 365
# 30h: 100%|██████████| 365/365 [10:51<00:00,  1.79s/it]
# Completed 30h - 2864 samples written

# %% [markdown]
# # Sanity read-in and batch check for once data is created

# %%
import tensorflow as tf
from data import _parse_batch

tfrecords_path = data_paths["TFRecords"]["tfrecords_path"]

dataset = tf.data.TFRecordDataset(os.path.join(tfrecords_path,'2018_30.3.tfrecords'),compression_type='GZIP') #'2018_30.3.tfrecords'

# %%
n_channels = len(all_fcst_fields) * 4
dataset = dataset.map(lambda x: _parse_batch(x, insize = (128,128,n_channels), consize=(128,128,2), outsize=(128,128,1)))
test = dataset.repeat().batch(2)
for inputs,outputs in test.take(1).as_numpy_iterator():

    print(inputs['lo_res_inputs'].shape)

    break
# Out:
# (2, 128, 128, 16)

# %%
import matplotlib.pyplot as plt
from data import all_fcst_fields

var = "sp"
idx = all_fcst_fields.index(var)*4
plt.imshow(inputs['lo_res_inputs'][0,:,:,idx],cmap='Blues')
